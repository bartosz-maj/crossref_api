# %% [markdown]
# crossref docs: https://github.com/CrossRef/rest-api-doc#readme
# crossref py: https://github.com/fabiobatalha/crossrefapi
# crossref R: https://github.com/ropensci/rcrossref

# %%
pip install crossrefapi
# Out:
# Collecting crossrefapi
#   Downloading crossrefapi-1.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from crossrefapi) (2.31.0)
# Collecting urllib3==1.26.16 (from crossrefapi)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->crossrefapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->crossrefapi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->crossrefapi) (2023.7.22)
# Installing collected packages: urllib3, crossrefapi
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed crossrefapi-1.6.0 urllib3-1.26.16

# %%
from urllib.request import urlopen

# %%
from crossref.restful import Works

# %%
import json

# %%
import pandas as pd

# %%
from tqdm import tqdm

# %%
class return_articles():
  def __init__(self, query_term, sample_size):
    self.query_term = query_term
    self.sample_size = sample_size

  def generate_output_list(self):
    output_list = []
    works = Works()
    query = works.query(self.query_term).sample(self.sample_size)
    for item in query:
      output_list.append(item)
    return output_list

  def generate_output_titles(self, input_list):
    output_titles = []
    output_json = []
    for i in input_list:
      if "title" in i.keys() and self.query_term in i["title"][0].lower():
        output_titles.append(i["title"][0])
        output_json.append(i)

    return output_titles, output_json

  def generate_output_df(self, filtered_json, required_elements):
    dict_list = []
    for i in range(0, len(filtered_json)):
      edited_json = dict.fromkeys(required_elements)
      for j in required_elements:
        edited_json[j] = filtered_json[i][j]

      dict_list.append(edited_json)
    df = pd.DataFrame.from_records(dict_list)

    return df

# %%
articles_gen = return_articles("responsible ai", 100)
unfiltered_json = articles_gen.generate_output_list()
output_titles, filtered_json = articles_gen.generate_output_titles(unfiltered_json)
output_df = articles_gen.generate_output_df(filtered_json, ["title", "DOI", "publisher"])

# %%
output_df
# Out:
#                                                 title  \
# 0               [Ensuring Responsible AI in Practice]
# 1                                    [Responsible AI]
# 2   [Is it possible to create a responsible AI tec...
# 3   [Review of: "Towards Responsible AI-Assisted S...
# 4                   [The challenge of responsible AI]
# 5   [A Pathway Towards Responsible AI Generated Co...
# 6   [Montreal Declaration for Responsible AI: 10 P...
# 7   [Designing Across Distributed Agency: Values, ...
# 8   [Ethical and Responsible AI (Security Privacy,...
# 9   [Could Responsible AI Change Recruiting for th...
# 10  [Review of: "Towards Responsible AI-Assisted S...
# 11  [Review of: "Towards Responsible AI-Assisted S...
# 12  [Factors Influencing the Adoption of Responsib...
# 13      [Causal Learning for Socially Responsible AI]
# 14  [Responsible AI, SDGs, and AI Governance in Af...
# 15  [Review of: "Towards Responsible AI-Assisted S...
# 16                  [Responsible AI for conservation]
# 17            [Defining a Sandbox for Responsible AI]
# 18      [Responsible AI: requirements and challenges]
# 19  [Responsible AI for Security Applications and ...
# 20  [Responsible AI and the smart home environment...
# 21  [Towards a roadmap on software engineering for...
# 22  [Review of: "Towards Responsible AI-Assisted S...
# 23  [The Building Blocks of a Responsible AI Pract...
# 24  [Responsible AI Understanding the Ethical and ...
# 25  [Harnessing Deep Learning for Efficient and Re...
# 26  [Human rights due diligence through responsibl...
# 27  [The Building Blocks of a Responsible AI Pract...
# 28  [Towards Responsible AI-Assisted Scholarship: ...
# 29  [Towards Socially Responsible AI: Cognitive Bi...
# 30  [The Application of the Principles of Responsi...
# 31  [Operationalizing Responsible AI at Scale: CSI...
# 32  [Responsible AI for labour market equality (BI...
# 33  [Socially Responsible AI Algorithms: Issues, P...
# 34  [Review of: "Towards Responsible AI-Assisted S...
# 35  [State of Responsible AI: Report reveals wides...
# 36  [Proceedings of the 1st Workshop on Software E...
# 37  [Responsible AI Systems: Who are the Stakehold...
# 38   [Responsible AI in Automatic Speech Recognition]
# 39    [AI and Ethics—Operationalizing Responsible AI]
# 40  [The Building Blocks of a Responsible AI Pract...
# 41      [Behavioral Use Licensing for Responsible AI]
# 42  [Responsible AI for Digital Health: a Synthesi...
# 43  [Tackling COVID-19 through Responsible AI Inno...
# 44  [Software engineering for Responsible AI: An e...
# 45  [Responsible AI and the Arts: The Ethical and ...
# 46  [Review of: "Towards Responsible AI-Assisted S...
# 47  [Collect, Measure, Repeat: Reliability Factors...
# 48  [Financial Risk Management and Explainable Tru...
# 49         [Developing Responsible AI Business Model]
#
#                                       DOI  \
# 0             10.1007/978-3-030-30371-6_6
# 1             10.1007/978-1-4842-6385-3_8
# 2              10.1007/s00146-021-01316-8
# 3                         10.32388/jyljh7
# 4             10.4337/9781839104398.00016
# 5                 10.24963/ijcai.2023/803
# 6                   10.31219/osf.io/sj2z5
# 7              10.21428/93b2c832.a9b1ae03
# 8                10.4324/9781003018810-26
# 9                 10.1287/lytx.2022.03.12
# 10                        10.32388/l086lv
# 11                        10.32388/9wss7f
# 12          10.1109/iceee59925.2023.00046
# 13                10.24963/ijcai.2021/598
# 14  10.23919/ist-africa56635.2022.9845598
# 15                        10.32388/oqimyi
# 16              10.1038/s42256-019-0022-7
# 17                   10.2139/ssrn.3255075
# 18              10.1186/s42467-019-0003-z
# 19              10.1017/9781009207898.034
# 20                  10.1049/icp.2023.2567
# 21                10.1145/3522664.3528607
# 22                        10.32388/e991bt
# 23           10.1109/mis.2023.3320438/mm4
# 24           10.1007/978-1-4842-9669-1_20
# 25                  10.31219/osf.io/jf9h2
# 26                    10.1787/31e7edcc-en
# 27               10.1109/mis.2023.3320438
# 28                        10.32388/7ovvw2
# 29               10.1609/aaai.v34i03.5654
# 30             10.1007/s10796-021-10191-z
# 31                        10.1145/3589946
# 32            10.4337/9781802204728.00014
# 33                   10.1613/jair.1.12814
# 34                        10.32388/9y5tht
# 35               10.1287/lytx.2021.03.16n
# 36                        10.1145/3526073
# 37                10.1145/3514094.3534187
# 38                10.1201/9781003300472-8
# 39            10.1007/978-3-030-72188-6_2
# 40           10.1109/mis.2023.3320438/mm9
# 41                10.1145/3531146.3533143
# 42             10.1007/s10796-021-10146-4
# 43              10.1162/99608f92.4bb9d7a7
# 44    10.1109/icse-seip55303.2022.9793864
# 45                10.1145/3597512.3597528
# 46                        10.32388/jueefv
# 47              10.1609/hcomp.v11i1.27547
# 48                   10.2139/ssrn.3873768
# 49           10.1007/978-3-031-09245-9_10
#
#                                             publisher
# 0                   Springer International Publishing
# 1                                              Apress
# 2             Springer Science and Business Media LLC
# 3                                           Qeios Ltd
# 4                             Edward Elgar Publishing
# 5   International Joint Conferences on Artificial ...
# 6                             Center for Open Science
# 7                                              PubPub
# 8                                           Routledge
# 9   Institute for Operations Research and the Mana...
# 10                                          Qeios Ltd
# 11                                          Qeios Ltd
# 12                                               IEEE
# 13  International Joint Conferences on Artificial ...
# 14                                               IEEE
# 15                                          Qeios Ltd
# 16            Springer Science and Business Media LLC
# 17                                        Elsevier BV
# 18            Springer Science and Business Media LLC
# 19                         Cambridge University Press
# 20          Institution of Engineering and Technology
# 21                                                ACM
# 22                                          Qeios Ltd
# 23  Institute of Electrical and Electronics Engine...
# 24                                             Apress
# 25                            Center for Open Science
# 26  Organisation for Economic Co-Operation and Dev...
# 27  Institute of Electrical and Electronics Engine...
# 28                                          Qeios Ltd
# 29  Association for the Advancement of Artificial ...
# 30            Springer Science and Business Media LLC
# 31          Association for Computing Machinery (ACM)
# 32                            Edward Elgar Publishing
# 33                               AI Access Foundation
# 34                                          Qeios Ltd
# 35  Institute for Operations Research and the Mana...
# 36                                                ACM
# 37                                                ACM
# 38                               Chapman and Hall/CRC
# 39                  Springer International Publishing
# 40  Institute of Electrical and Electronics Engine...
# 41                                                ACM
# 42            Springer Science and Business Media LLC
# 43                               MIT Press - Journals
# 44                                               IEEE
# 45                                                ACM
# 46                                          Qeios Ltd
# 47  Association for the Advancement of Artificial ...
# 48                                        Elsevier BV
# 49                  Springer International Publishing

# %%
output_df.to_csv("df.csv", index = False)
